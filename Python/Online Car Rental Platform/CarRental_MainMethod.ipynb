# %%
import datetime

# %%
from datetime import datetime

# %%
import CarProj_1_C1

# %%
from CarProj_1_C1 import Car_Rental_Company,Customer,Booking,custlist,custdetail

# %%
def main():
    A1 = Car_Rental_Company() 
    A1.display_Car_Rental_info() 
    A1.display_cars()
    A2 = Customer()
    A3 = Booking(A2)
    A3.get_user_action()
    print("Thank you! Have a Nice Day!")

# %%
main()
# Out:
# *******Welcome to ABC Car Rental Car Rental Company*********
# Manchester
# 1122112211
# abcrental@abc.com
#
# **********************Available Cars**********************
# Car ID	Car Type	Availability
# 1	ECONOMY		10
# 2	SUV		8
# 3	COMPACT		15
# **Price Mode**
# Hourly : $20	Daily : $15	Weekly : $10
#
# Would you like to rent or return the car
# Enter 1-Rent or 2-Return or 3-Exit : 1
#
# Thank you! for choosing the service
#
# Enter Name : Yamuna
# Enter Address : 123 Downey Dr
# Enter Contact No : 7678909987
# Enter Email Id : yamuna@gmail.com
# Enter Driver Id : RTY6787
#
# Enter pickup date in YYYY-MM-DD format : 2021-07-07
# Enter pickup time in HH:MM:SS format : 02:30:00
#
# Pickup date and time is : 2021-07-07 02:30:00
#
# Enter Price Mode:
# Hourly = 1
# Daily = 2
# Weekly = 3 : 1
# Enter the Car ID (1\2\3) :1
# Enter the number of cars for pickup : 3
#
# Car booked succesfully
#
# **Receipt Created**
# Receipt ID : 1110
# Car ID : 1
# No of Cars : 3
# Price Mode : 1
# ...

# %%
custlist
# Out:
# {1110: [1, 'RTY6787', 1, 3, 1, datetime.datetime(2021, 7, 7, 2, 30)],
#  1120: [2, 'RTEF3425', 3, 2, 2, datetime.datetime(2021, 7, 15, 6, 30)],
#  1130: [1, 'RTEF3425', 1, 2, 2, datetime.datetime(2021, 7, 11, 9, 30)]}

# %%
custdetail
# Out:
# {1110: ['Yamuna', '123 Downey Dr', 7678909987, 'yamuna@gmail.com', 'RTY6787'],
#  1120: ['Usha', '56 St street', 6789876789, 'usha@gmail', 'RTYG6789'],
#  1130: ['Ravi', '9 rosy st', 987656789, 'ravi@gmail', 'RTEF3425']}
